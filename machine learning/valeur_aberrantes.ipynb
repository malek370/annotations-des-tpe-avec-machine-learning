# %% [markdown]
# voir et traiter les valeur aberrantes

# %%
import pandas as pd
import seaborn as sns
import pickle
from sklearn.impute import SimpleImputer,KNNImputer
import seaborn as sns
from sklearn.feature_selection import mutual_info_classif
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import Normalizer ,MinMaxScaler
df=pd.read_excel('data/Data_TPE_Stagiaire.xlsx')
df.rename(columns={'NUM CLT':'NUM_CLT'},inplace=True)
df=df.dropna()

# %%
df.columns
# Out:
# Index(['NUM_CLT', 'ANNEE', 'ACT_COURANT', 'PASS_COURANT', 'STOCKS', 'LIQ',
#        'FPN', 'TOT_BL', 'DS', 'CAP_PROP', 'CP', 'DS.1', 'CFN', 'FR', 'BFR',
#        'CA', 'CLIENTS', 'FOURNISSEURS', 'RN', 'DS_FPN', 'DT_CAP_PROP',
#        'LIQ_GENERALE', 'LIQ_REDUITE', 'LIQ_IMMEDIAT', 'SOLVABILITE',
#        'CAP_PROP_CP', 'DS_CFN', 'FR_BFR', 'CA_CAP_PROP', 'CA_TOT_BL', 'D_CLT',
#        'D_FOURN', 'D_STK', 'ROA', 'ROE', 'RN_CA', 'DEFAUT'],
#       dtype='object')

# %%
#utiliser col=col+1 juste pour faciliter le travail (copier coller a chaque fois pour passer au variable suivante)
col=2
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
col=19
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
sns.boxplot(df[[df.columns[col]]])
col=col+1
plt.show()

# %%
# j'ai chercher l'index des valeurs aberrantes
abval={'ACT_COURANT': [3767, 5258, 5985],
 'FPN': [3767, 5258, 5985],
 'TOT_BL': [3767, 5258, 5985],
 'CAP_PROP': [3767, 5258, 5985],
 'CP': [3767, 5258, 5985],
 'FR': [3767, 5258, 5985],
 'BFR': [3767, 5258, 5985],
 'CLIENTS': [3502, 6925],
 'FOURNISSEURS': [3006],
 'DS_FPN': [3596, 4875, 5774, 4635],
 'DT_CAP_PROP': [1972, 2300, 3353],
 'LIQ_GENERALE': [4360, 5693, 5693],
 'LIQ_REDUITE': [4360, 5693],
 'LIQ_IMMEDIAT': [1446, 2192, 3024, 5693],
 'SOLVABILITE': [2032, 370, 5537],
 'CAP_PROP_CP': [6038, 5066],
 'DS_CFN': [5410, 1890, 5710],
 'FR_BFR': [6878, 2707, 7633],
 'CA_CAP_PROP': [4906, 5327, 502, 1113],
 'D_STK': [1709],
 'RN_CA': [3239, 4315],
 'ROA': [2032, 6172]}
# Out:
# {'ACT_COURANT': [3767, 5258, 5985],
#  'FPN': [3767, 5258, 5985],
#  'TOT_BL': [3767, 5258, 5985],
#  'CAP_PROP': [3767, 5258, 5985],
#  'CP': [3767, 5258, 5985],
#  'FR': [3767, 5258, 5985],
#  'BFR': [3767, 5258, 5985],
#  'CLIENTS': [3502, 6925],
#  'FOURNISSEURS': [3006],
#  'DS_FPN': [3596, 4875, 5774, 4635],
#  'DT_CAP_PROP': [1972, 2300, 3353],
#  'LIQ_GENERALE': [4360, 5693, 5693],
#  'LIQ_REDUITE': [4360, 5693],
#  'LIQ_IMMEDIAT': [1446, 2192, 3024, 5693],
#  'SOLVABILITE': [2032, 370, 5537],
#  'CAP_PROP_CP': [6038, 5066],
#  'DS_CFN': [5410, 1890, 5710],
#  'FR_BFR': [6878, 2707, 7633],
#  'CA_CAP_PROP': [4906, 5327, 502, 1113],
#  'D_STK': [1709],
#  'RN_CA': [3239, 4315],
#  'ROA': [2032, 6172]}

# %%
#enregistre deja pa besoin de le refaire
#abval=pickle.load(open('data/lines_aberrant.pickle','rb'))
